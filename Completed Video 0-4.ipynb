# %%
# Install required libraries (run this once)
import rdkit
import pandas as pd
import sklearn
import matplotlib

print("RDKit version:", rdkit.__version__)
print("Pandas version:", pd.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Matplotlib version:", matplotlib.__version__)

 # Quick RDKit test
from rdkit import Chem
from rdkit.Chem import Draw

mol = Chem.MolFromSmiles('CCO') # ethanol
print("Molecule created:", mol) # This will display the molecule
Draw.MolToImage(mol)
# Out:
# RDKit version: 2025.09.6
# Pandas version: 2.3.3
# Scikit-learn version: 1.7.2
# Matplotlib version: 3.10.8
# Molecule created: <rdkit.Chem.rdchem.Mol object at 0x0000023981761700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# Aspirin SMILES
aspirin_smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"

# Create molecule object
mol = Chem.MolFromSmiles(aspirin_smiles)

# Draw the molecule (image will appear in notebook)
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# List of SMILES (aspirin, caffeine, ibuprofen, ethanol)
smiles_list = [
    "CC(=O)OC1=CC=CC=C1C(=O)O",  # aspirin
    "CN1C=NC2=C1C(=O)N(C(=O)N2C)C",  # caffeine
    "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O",  # ibuprofen
    "CCO"  # ethanol
]

# Convert to molecule objects
mols = [Chem.MolFromSmiles(s) for s in smiles_list]

# Draw grid
img = Draw.MolsToGridImage(mols, molsPerRow=2, subImgSize=(200,200))
img

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# Load a molecule
smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"  # Aspirin
mol = Chem.MolFromSmiles(smiles)

# Available Lipinski rule calculators
print("Lipinski Rule Calculators in RDKit:")
print("-" * 35)
print("1. Molecular Weight:", Descriptors.MolWt)
print("2. LogP:", Descriptors.MolLogP)
print("3. H-Bond Donors:", Lipinski.NumHDonors)
print("4. H-Bond Acceptors:", Lipinski.NumHAcceptors)
print("5. Rotatable Bonds:", Lipinski.NumRotatableBonds)
print("6. Ring Count:", Lipinski.RingCount)

# Show they are callable functions
print("\nExample usage on aspirin:")
print(f"Call any function with: function_name(mol)")
# Out:
# Lipinski Rule Calculators in RDKit:
# -----------------------------------
# 1. Molecular Weight: <function <lambda> at 0x00000150065C2B90>
# 2. LogP: <function <lambda> at 0x000001500655BAC0>
# 3. H-Bond Donors: <function <lambda> at 0x00000150065ED7E0>
# 4. H-Bond Acceptors: <function <lambda> at 0x00000150065EDA20>
# 5. Rotatable Bonds: <function <lambda> at 0x00000150065EDC60>
# 6. Ring Count: <function <lambda> at 0x00000150065EDEA0>
#
# Example usage on aspirin:
# Call any function with: function_name(mol)

# %%
from rdkit import Chem
from rdkit.Chem import Lipinski

# Aspirin
smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"
mol = Chem.MolFromSmiles(smiles)
hbd = Lipinski.NumHDonors(mol)
print(f"Aspirin H-bond donors: {hbd}")

# Caffeine
caffeine_smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"
mol_caf = Chem.MolFromSmiles(caffeine_smiles)
hbd_caf = Lipinski.NumHDonors(mol_caf)
print(f"Caffeine H-bond donors: {hbd_caf}")

# Ibuprofen
ibuprofen_smiles = "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"
mol_ibu = Chem.MolFromSmiles(ibuprofen_smiles)
hbd_ibu = Lipinski.NumHDonors(mol_ibu)
print(f"Ibuprofen H-bond donors: {hbd_ibu}")
# Out:
# Aspirin H-bond donors: 1
# Caffeine H-bond donors: 0
# Ibuprofen H-bond donors: 1

# %%
from rdkit import Chem
from rdkit.Chem import Lipinski

# Aspirin
smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"
mol = Chem.MolFromSmiles(smiles)
hba = Lipinski.NumHAcceptors(mol)
print(f"Aspirin H-bond acceptors: {hba}")

# Caffeine
caffeine_smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"
mol_caf = Chem.MolFromSmiles(caffeine_smiles)
hba_caf = Lipinski.NumHAcceptors(mol_caf)
print(f"Caffeine H-bond acceptors: {hba_caf}")

# Paracetamol
para_smiles = "CC(=O)NC1=CC=C(O)C=C1"
mol_para = Chem.MolFromSmiles(para_smiles)
hba_para = Lipinski.NumHAcceptors(mol_para)
print(f"Paracetamol H-bond acceptors: {hba_para}")
# Out:
# Aspirin H-bond acceptors: 3
# Caffeine H-bond acceptors: 3
# Paracetamol H-bond acceptors: 2

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

# Aspirin
smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"
mol = Chem.MolFromSmiles(smiles)
logp = Descriptors.MolLogP(mol)
print(f"Aspirin LogP: {logp:.2f}")

# Ibuprofen
ibuprofen_smiles = "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"
mol_ibu = Chem.MolFromSmiles(ibuprofen_smiles)
logp_ibu = Descriptors.MolLogP(mol_ibu)
print(f"Ibuprofen LogP: {logp_ibu:.2f}")

# Caffeine
caffeine_smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"
mol_caf = Chem.MolFromSmiles(caffeine_smiles)
logp_caf = Descriptors.MolLogP(mol_caf)
print(f"Caffeine LogP: {logp_caf:.2f}")
# Out:
# Aspirin LogP: 1.31
# Ibuprofen LogP: 3.07
# Caffeine LogP: -1.03

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

drugs = [
    ("Aspirin", "CC(=O)OC1=CC=CC=C1C(=O)O"),
    ("Ibuprofen", "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"),
    ("Caffeine", "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"),
    ("Paracetamol", "CC(=O)NC1=CC=C(O)C=C1")
]

for name, smiles in drugs:
    mol = Chem.MolFromSmiles(smiles)
    mw = Descriptors.MolWt(mol)
    print(f"{name}: {mw:.1f} g/mol")
# Out:
# Aspirin: 180.2 g/mol
# Ibuprofen: 206.3 g/mol
# Caffeine: 194.2 g/mol
# Paracetamol: 151.2 g/mol

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

# Aspirin
smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"
mol = Chem.MolFromSmiles(smiles)
tpsa = Descriptors.TPSA(mol)
print(f"Aspirin TPSA: {tpsa:.1f} Å²")

# Paracetamol
para_smiles = "CC(=O)NC1=CC=C(O)C=C1"
mol_para = Chem.MolFromSmiles(para_smiles)
tpsa_para = Descriptors.TPSA(mol_para)
print(f"Paracetamol TPSA: {tpsa_para:.1f} Å²")

# Ibuprofen
ibu_smiles = "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"
mol_ibu = Chem.MolFromSmiles(ibu_smiles)
tpsa_ibu = Descriptors.TPSA(mol_ibu)
print(f"Ibuprofen TPSA: {tpsa_ibu:.1f} Å²")
# Out:
# Aspirin TPSA: 63.6 Å²
# Paracetamol TPSA: 49.3 Å²
# Ibuprofen TPSA: 37.3 Å²

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

drugs = [
    ("Aspirin", "CC(=O)OC1=CC=CC=C1C(=O)O"),
    ("Ibuprofen", "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"),
    ("Caffeine", "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"),
    ("Paracetamol", "CC(=O)NC1=CC=C(O)C=C1"),
    ("Ethanol", "CCO")
]

print("Drug        MW    LogP  HBD  HBA  TPSA   Lipinski")
print("-" * 60)

for name, smiles in drugs:
    mol = Chem.MolFromSmiles(smiles)
    mw = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Lipinski.NumHDonors(mol)
    hba = Lipinski.NumHAcceptors(mol)
    tpsa = Descriptors.TPSA(mol)
    
    violations = 0
    if mw >= 500: violations += 1
    if logp >= 5: violations += 1
    if hbd >= 5: violations += 1
    if hba >= 10: violations += 1
    
    status = "Pass" if violations == 0 else f"Fail ({violations} violations)"
    
    print(f"{name:10} {mw:5.0f} {logp:5.2f} {hbd:4} {hba:4} {tpsa:6.1f}   {status}")
# Out:
# Drug        MW    LogP  HBD  HBA  TPSA   Lipinski
# ------------------------------------------------------------
# Aspirin      180  1.31    1    3   63.6   Pass
# Ibuprofen    206  3.07    1    1   37.3   Pass
# Caffeine     194 -1.03    0    3   61.8   Pass
# Paracetamol   151  1.35    2    2   49.3   Pass
# Ethanol       46 -0.00    1    1   20.2   Pass

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

drugs = [
    ("Aspirin", "CC(=O)OC1=CC=CC=C1C(=O)O"),
    ("Ibuprofen", "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O"),
    ("Caffeine", "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"),
    ("Paracetamol", "CC(=O)NC1=CC=C(O)C=C1")
]

print("Drug        MW    LogP  HBD  HBA  Pass/Fail")
print("-" * 45)

for name, smiles in drugs:
    mol = Chem.MolFromSmiles(smiles)
    mw = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Lipinski.NumHDonors(mol)
    hba = Lipinski.NumHAcceptors(mol)
    
    violations = 0
    if mw >= 500: violations += 1
    if logp >= 5: violations += 1
    if hbd >= 5: violations += 1
    if hba >= 10: violations += 1
    
    status = "PASS" if violations == 0 else f"FAIL ({violations})"
    
    print(f"{name:10} {mw:5.1f} {logp:5.2f} {hbd:4} {hba:4}  {status}")
# Out:
# Drug        MW    LogP  HBD  HBA  Pass/Fail
# ---------------------------------------------
# Aspirin    180.2  1.31    1    3  PASS
# Ibuprofen  206.3  3.07    1    1  PASS
# Caffeine   194.2 -1.03    0    3  PASS
# Paracetamol 151.2  1.35    2    2  PASS
